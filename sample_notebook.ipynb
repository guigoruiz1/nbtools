# %% [markdown]
# Table of Contents <a class="jp-toc-ignore"></a>
# =================
# * [1 Introduction](#Introduction)
#   * [1.1 Getting Started](#Getting-Started)
# * [2 Data Processing](#Data-Processing)
#   * [2.1 Loading Data](#Loading-Data)
#   * [2.2 Preprocessing](#Preprocessing)
# * [3 Analysis](#Analysis)
#   * [3.1 Statistical Summary](#Statistical-Summary)
#     * [3.1.1 Visualization](#Visualization)
# * [4 Conclusion](#Conclusion)

# %% [markdown]
# # Introduction
#
# This is a sample notebook to test the heading numbering and table of contents generation.

# %% [markdown]
# ## Getting Started
#
# First, let's import the necessary libraries.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Data Processing
#
# Now let's process some data.

# %% [markdown]
# ## Loading Data
#
# Load the dataset from a file.

# %%
# Create sample data
data = {"name": ["Alice", "Bob", "Charlie"], "age": [25, 30, 35]}
df = pd.DataFrame(data)
print(df)

# %% [markdown]
# ## Preprocessing
#
# Clean and prepare the data.

# %%
# Remove any missing values
df = df.dropna()

# %% [markdown]
# # Analysis
#
# Analyze the processed data.

# %% [markdown]
# ## Statistical Summary
#
# Display basic statistics.

# %%
print(df.describe())

# %% [markdown]
# ### Visualization
#
# Create visual representations of the data.

# %%
# Plot age distribution
df["age"].plot(kind="bar")

# %% [markdown]
# # Conclusion
#
# This concludes the analysis.
